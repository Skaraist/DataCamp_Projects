# %% [markdown]
# <img src=https://media.wired.com/photos/59328fcc5c4fbd732b5538f4/master/w_2560%2Cc_limit/bike-share-660.jpg width=200 align=right>
#
#
# <h1><left>SF Area Bikeshare Analysis</left></h1>

# %% [markdown]
# # Index
#
# ## [- General Settings](#GeneralSettings)
#
# ## [- Data Gatering](#DataGatering)
#
#
# ## [- Data Assesing](#DataAssessing)
#
#
# ## [- Data Cleaning/Data Transforming](#DataCleaning/DataTransforming)
#
#
# ## [- Data Analysis](#DataAnalysis)
#
#
# ## [- Conclusion](#Conclusion)
#
#
# ## [- Next Steps](#NextSteps)
#
#
# ## [- Plan execution](#Planexecution)

# %% [markdown]
# <a id="GeneralSettings"></a>
# # General Settings

# %%
#Importing libraries
import numpy as np
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt
import seaborn as sns
import timeit

# %% [markdown]
# <a id="DataGatering"></a>
# # Data Gatering

# %% [markdown]
# ## Using a provided sqlite

# %%
#Getting bikes dataset from desktop
con = sqlite3.connect("D://Escritorio//Bike Files//database.sqlite")
cur = con.cursor()

# %%
#Checking which tables we have available for analysis
pd.read_sql_query('SELECT name FROM sqlite_master', con)
# Out:
#       name
# 0  station
# 1   status
# 2     trip
# 3  weather

# %%
#Checking the station table
pd.read_sql_query('SELECT * FROM station LIMIT 5', con)
# Out:
#    id                               name        lat        long  dock_count  \
# 0   2  San Jose Diridon Caltrain Station  37.329732 -121.901782          27
# 1   3              San Jose Civic Center  37.330698 -121.888979          15
# 2   4             Santa Clara at Almaden  37.333988 -121.894902          11
# 3   5                   Adobe on Almaden  37.331415 -121.893200          19
# 4   6                   San Pedro Square  37.336721 -121.894074          15
#
#        city installation_date
# 0  San Jose          8/6/2013
# 1  San Jose          8/5/2013
# 2  San Jose          8/6/2013
# 3  San Jose          8/5/2013
# 4  San Jose          8/7/2013

# %%
#Checking the status table
pd.read_sql_query('SELECT * FROM status LIMIT 5', con)
# Out:
#    station_id  bikes_available  docks_available                 time
# 0           2                2               25  2013/08/29 12:06:01
# 1           2                2               25  2013/08/29 12:07:01
# 2           2                2               25  2013/08/29 12:08:01
# 3           2                2               25  2013/08/29 12:09:01
# 4           2                2               25  2013/08/29 12:10:01

# %%
#Checking the trip table
pd.read_sql_query('SELECT * FROM trip LIMIT 5', con)
# Out:
#      id  duration      start_date        start_station_name  start_station_id  \
# 0  4069       174  8/29/2013 9:08         2nd at South Park                64
# 1  4073      1067  8/29/2013 9:24  South Van Ness at Market                66
# 2  4074      1131  8/29/2013 9:24  South Van Ness at Market                66
# 3  4075      1117  8/29/2013 9:24  South Van Ness at Market                66
# 4  4076      1118  8/29/2013 9:25  South Van Ness at Market                66
#
#          end_date                         end_station_name  end_station_id  \
# 0  8/29/2013 9:11                        2nd at South Park              64
# 1  8/29/2013 9:42  San Francisco Caltrain 2 (330 Townsend)              69
# 2  8/29/2013 9:43  San Francisco Caltrain 2 (330 Townsend)              69
# 3  8/29/2013 9:43  San Francisco Caltrain 2 (330 Townsend)              69
# 4  8/29/2013 9:43  San Francisco Caltrain 2 (330 Townsend)              69
#
#    bike_id subscription_type  zip_code
# 0      288        Subscriber     94114
# 1      321        Subscriber     94703
# 2      317        Subscriber     94115
# 3      316        Subscriber     94122
# 4      322        Subscriber     94597

# %%
#Checking the weather table
pd.read_sql_query('SELECT * FROM weather LIMIT 5', con)
# Out:
#         date  max_temperature_f  mean_temperature_f  min_temperature_f  \
# 0  8/29/2013                 74                  68                 61
# 1  8/30/2013                 78                  69                 60
# 2  8/31/2013                 71                  64                 57
# 3   9/1/2013                 74                  66                 58
# 4   9/2/2013                 75                  69                 62
#
#    max_dew_point_f  mean_dew_point_f  min_dew_point_f  max_humidity  \
# 0               61                58               56            93
# 1               61                58               56            90
# 2               57                56               54            93
# 3               60                56               53            87
# 4               61                60               58            93
#
#    mean_humidity  min_humidity  ...  mean_visibility_miles  \
# 0             75            57  ...                     10
# 1             70            50  ...                     10
# 2             75            57  ...                     10
# 3             68            49  ...                     10
# 4             77            61  ...                     10
#
#    min_visibility_miles  max_wind_Speed_mph  mean_wind_speed_mph  \
# 0                    10                  23                   11
# 1                     7                  29                   13
# 2                    10                  26                   15
# 3                    10                  25                   13
# 4                     6                  23                   12
#
#    max_gust_speed_mph  precipitation_inches  cloud_cover  events  \
# 0                  28                     0            4
# 1                  35                     0            2
# 2                  31                     0            4
# 3                  29                     0            4
# 4                  30                     0            6
#
#    wind_dir_degrees  zip_code
# 0               286     94107
# 1               291     94107
# 2               284     94107
# 3               284     94107
# 4               277     94107
#
# [5 rows x 24 columns]

# %% [markdown]
# <a id="DataAssessing"></a>
# #  Data Assessing

# %% [markdown]
# ## Visual Assesing

# %%
#Checking the size of every db
pd.read_sql_query('SELECT COUNT(*) FROM station', con)
# Out:
#    COUNT(*)
# 0        70

# %%
#Checking the size of every db
pd.read_sql_query('SELECT COUNT(*) FROM status', con)
# Out:
#    COUNT(*)
# 0  71984434

# %%
#Checking the size of every db
pd.read_sql_query('SELECT COUNT(*) FROM trip', con)
# Out:
#    COUNT(*)
# 0    669959

# %%
#Checking the size of every db
pd.read_sql_query('SELECT COUNT(*) FROM weather', con)
# Out:
#    COUNT(*)
# 0      3665

# %% [markdown]
# ## Programmatically Assesing

# %%
#Converting the smallers tables into df
station_df = pd.read_sql_query('SELECT * FROM station', con)
trip_df = pd.read_sql_query('SELECT * FROM trip', con)
weather_df =pd.read_sql_query('SELECT * FROM weather', con)

# %%
#Getting dtype and null information from station
station_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 70 non-null     int64
#  1   name               70 non-null     object
#  2   lat                70 non-null     float64
#  3   long               70 non-null     float64
#  4   dock_count         70 non-null     int64
#  5   city               70 non-null     object
#  6   installation_date  70 non-null     object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 4.0+ KB

# %%
#Getting dtype and null information from trip
trip_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 669959 entries, 0 to 669958
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  669959 non-null  int64
#  1   duration            669959 non-null  int64
#  2   start_date          669959 non-null  object
#  3   start_station_name  669959 non-null  object
#  4   start_station_id    669959 non-null  int64
#  5   end_date            669959 non-null  object
#  6   end_station_name    669959 non-null  object
#  7   end_station_id      669959 non-null  int64
#  8   bike_id             669959 non-null  int64
#  9   subscription_type   669959 non-null  object
#  10  zip_code            669959 non-null  object
# dtypes: int64(5), object(6)
# memory usage: 56.2+ MB

# %%
#Getting dtype and null information from weather
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3665 entries, 0 to 3664
# Data columns (total 24 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   date                            3665 non-null   object
#  1   max_temperature_f               3665 non-null   object
#  2   mean_temperature_f              3665 non-null   object
#  3   min_temperature_f               3665 non-null   object
#  4   max_dew_point_f                 3665 non-null   object
#  5   mean_dew_point_f                3665 non-null   object
#  6   min_dew_point_f                 3665 non-null   object
#  7   max_humidity                    3665 non-null   object
#  8   mean_humidity                   3665 non-null   object
#  9   min_humidity                    3665 non-null   object
#  10  max_sea_level_pressure_inches   3665 non-null   object
#  11  mean_sea_level_pressure_inches  3665 non-null   object
#  12  min_sea_level_pressure_inches   3665 non-null   object
#  13  max_visibility_miles            3665 non-null   object
#  14  mean_visibility_miles           3665 non-null   object
#  15  min_visibility_miles            3665 non-null   object
#  16  max_wind_Speed_mph              3665 non-null   object
#  17  mean_wind_speed_mph             3665 non-null   object
#  18  max_gust_speed_mph              3665 non-null   object
#  19  precipitation_inches            3665 non-null   object
#  20  cloud_cover                     3665 non-null   object
#  21  events                          3665 non-null   object
#  22  wind_dir_degrees                3665 non-null   object
#  23  zip_code                        3665 non-null   int64
# dtypes: int64(1), object(23)
# memory usage: 687.3+ KB

# %% [markdown]
# ### Gatering and asessing comments
# - There is no null values in the tables weather, trip or station
# - The "status" table is so big that would be better to analyze it with some tools that can work with SQL. It would need a "manual analysis"
# - Taking in consideration that 3 of 4 tables has no nulls. We are going to assume that the table "status" has the same behavior
# - The temperature are on Fahrenheit so we will need to convert it for a better understanding.
# - There is two types of suscripiption_type. We are going to focus in the "subscriber" type because that is the one that we do not want to lose as a client.
# - There is 2 "rain" events. we need to standardize that
# - So many variables are in object format when they need to be in integer or float format. We need to change the format of the ones that are we going to use in our analysis

# %% [markdown]
# <a id="DataCleaning/DataTransforming"></a>
# # Data Cleaning/Data Transforming

# %% [markdown]
# ## Weather Table

# %%
#Making copies of the original dataframe
weather_clean = weather_df.copy()

# %% [markdown]
# ### Fixing events

# %%
#Fixing the Rain event
weather_clean["events"] = weather_clean["events"].str.replace("rain","Rain")
weather_clean["events"].value_counts()
# Out:
#                      3143
# Rain                  390
# Fog                   112
# Fog-Rain               17
# Rain-Thunderstorm       3
# Name: events, dtype: int64

# %% [markdown]
# ### Fixing temperatures

# %%
#Changing the type of variable from the temperatures
weather_clean[['max_temperature_f', 'min_temperature_f','mean_temperature_f']] = weather_clean[['max_temperature_f', 'min_temperature_f','mean_temperature_f']].apply(pd.to_numeric)

#Generating a temperature value in celsius
weather_clean["max_temp_c"] = (weather_clean['max_temperature_f'] - 32)*(5/9)
weather_clean["min_temp_C"] = (weather_clean['min_temperature_f'] - 32)*(5/9)
weather_clean["mean_temp_C"] = (weather_clean['mean_temperature_f'] - 32)*(5/9)

#Converting the temperature in a value with just two decimals
weather_clean[["max_temp_c","min_temp_C","mean_temp_C"]] = weather_clean[["max_temp_c","min_temp_C","mean_temp_C"]].round(2)

# %% [markdown]
# ### Fixing precipitations

# %%
#Checking the values for precipitation
weather_clean["precipitation_inches"].value_counts()
# Out:
# 0       3231
# T        143
# 0.01      65
# 0.02      29
# 0.03      13
#         ...
# 0.4        1
# 1.28       1
# 3.23       1
# 3.36       1
# 0.69       1
# Name: precipitation_inches, Length: 86, dtype: int64

# %%
#Droping the rows where prcipitations = "T". 
#We do that because it just mean to drop the 3% of or data. Is not significant for our analysis
#And it is better than guess which number goes there
weather_clean = weather_clean[weather_clean["precipitation_inches"] != "T"]

#Erasing the one row that does not have a precipitation value
weather_clean = weather_clean[weather_clean["precipitation_inches"] != '']

weather_clean["precipitation_inches"] = weather_clean["precipitation_inches"].astype(float)

# %% [markdown]
# ### Fixing date format

# %%
weather_clean['date'] = pd.to_datetime(weather_clean['date'])

# %% [markdown]
# <a id="DataAnalysis"></a>
# ## Data Analysis

# %% [markdown]
# #### Scope
# - Taking in consideration that the NPS variable is not available in the tables the first call would be to ask for this variable to improve the analysis.
# - Taking in consideration This is just an example case. We are going to create a hypothesis to try to find variables that could affect an NPS
#
# - We are going to check 4 Hypothesis:
#     * 1.- In the later months the heat has growth, and the people is not comfortable with that affecting the NPS
#     * 2.- In the later months the precipitations have growth, and the people is not comfortable with that affecting the NPS
#     * 3.- There are stations with less docks and people is not comfortable with that affecting the NPS
#     * 4.- The stations are far from each other, and people is not comfortable with that affecting the NPS
#
# - Extra Analysis
#     * Would be interesting to know the different behavior for customers and subscribers
#     * Would be interesting to know which ones are the most popular routes

# %% [markdown]
# #### Analyzing if the temperature could be affecting the NPS

# %%
#Creating a new df to use in the graph
to_graph  = weather_clean.groupby(by="date")["mean_temp_C"].mean()

#Cleaning the indexes
temperature = pd.DataFrame(to_graph).reset_index()

# %%
#Generating a line chart for the temperature
plt.figure(figsize=(12,12))

X = temperature["date"]
Y = temperature["mean_temp_C"]

plt.plot(X, Y)
plt.show()

# %% [markdown]
# #### Analyzing if the precipitations could be affecting the NPS

# %%
#Creating a new df to use in the graph
to_graph  = weather_clean.groupby(by="date")["precipitation_inches"].mean()

#Cleaning the indexes
precipitation = pd.DataFrame(to_graph).reset_index()

# %%
#Generating a line chart for the precipitations
plt.figure(figsize=(12,12))

X = precipitation["date"]
Y = precipitation["precipitation_inches"]

x = ["2013-08-29","2015-08-31"]

#Creating lines to define difrent clasifications for rain
y = [0.3] * 733
y1 = [0.1] * 733

plt.plot(X,y1)
plt.plot(X,y)
plt.plot(X, Y)
plt.show()

#Rainfall rate is generally described as light, moderate or heavy. 
#Light rainfall is considered less than 0.10 inches of rain per hour. 
#Moderate rainfall measures 0.10 to 0.30 inches of rain per hour. 
#Heavy rainfall is more than 0.30 inches of rain per hour.

# %% [markdown]
# #### Analyzing if the number of docks could be affecting the NPS

# %%
#Defining the conditions for the colors
conditions = [
    (station_df["city"] == 'San Francisco'),
    (station_df["city"] == 'San Jose'),
    (station_df["city"] == 'Redwood City'),
    (station_df["city"] == 'Mountain View'),
    (station_df["city"] == 'Palo Alto')
    ]

values = ['powderblue', 'lightcoral', 'moccasin', 'mediumblue',"lightsteelblue"]

# create a new column and use np.select to assign values to it using our lists as arguments
station_df['colors'] = np.select(conditions, values)

# display updated DataFrame
station_df.head()
# Out:
#    id                               name        lat        long  dock_count  \
# 0   2  San Jose Diridon Caltrain Station  37.329732 -121.901782          27
# 1   3              San Jose Civic Center  37.330698 -121.888979          15
# 2   4             Santa Clara at Almaden  37.333988 -121.894902          11
# 3   5                   Adobe on Almaden  37.331415 -121.893200          19
# 4   6                   San Pedro Square  37.336721 -121.894074          15
#
#        city installation_date      colors
# 0  San Jose          8/6/2013  lightcoral
# 1  San Jose          8/5/2013  lightcoral
# 2  San Jose          8/6/2013  lightcoral
# 3  San Jose          8/5/2013  lightcoral
# 4  San Jose          8/7/2013  lightcoral

# %%
station_df["city"].value_counts()
# Out:
# San Francisco    35
# San Jose         16
# Redwood City      7
# Mountain View     7
# Palo Alto         5
# Name: city, dtype: int64

# %%
#Generating a bar chart for the number of docks
plt.figure(figsize=(12,12))

c = station_df['colors']

#Creating the chart
plt.bar(station_df["id"], station_df["dock_count"], color = c)

plt.title('ID Vs Number of docks')
plt.xlabel('ID')
plt.ylabel('Number of docks')
plt.show()

# %% [markdown]
# #### Analyzing if the number of docks could be affecting the NPS

# %%
#defiining colors for the graph
values = ["red","blue","yellow","green","black"]

station_df['colors'] = np.select(conditions, values)

cr = station_df['colors']

#Creating the chart
plt.figure(figsize=(12,12))
plt.scatter(station_df["lat"], station_df["long"], color = cr)
plt.show()

# %% [markdown]
# #### Analyzing the number of travels per client

# %%
#Remomving duration outliers
trip_df = trip_df[trip_df["duration"]<= 1000000]

#Defining colors for Subscription_type
colors = {"Subscriber":'orange', "Customer":"blue"}

#Creating the chart
plt.figure(figsize=(12,12))
sns.scatterplot(data = trip_df, x = "duration", y = "id",c=trip_df["subscription_type"].map(colors))
# Out:
# <AxesSubplot:xlabel='duration', ylabel='id'>

# %%
#Checking some stadistics for the numeric variables in trip 
trip_df.describe()
# Out:
#                   id       duration  start_station_id  end_station_id  \
# count  669955.000000  669955.000000     669955.000000   669955.000000
# mean   460380.302077    1074.531037         57.851909       57.837489
# std    264584.192699    6026.465054         17.112452       17.200136
# min      4069.000000      60.000000          2.000000        2.000000
# 25%    231081.500000     344.000000         50.000000       50.000000
# 50%    459272.000000     517.000000         62.000000       62.000000
# 75%    692598.500000     755.000000         70.000000       70.000000
# max    913460.000000  722236.000000         84.000000       84.000000
#
#              bike_id
# count  669955.000000
# mean      427.587272
# std       153.450940
# min         9.000000
# 25%       334.000000
# 50%       440.000000
# 75%       546.000000
# max       878.000000

# %%
trip_df
# Out:
#             id  duration       start_date  \
# 0         4069       174   8/29/2013 9:08
# 1         4073      1067   8/29/2013 9:24
# 2         4074      1131   8/29/2013 9:24
# 3         4075      1117   8/29/2013 9:24
# 4         4076      1118   8/29/2013 9:25
# ...        ...       ...              ...
# 669954  913453       789  8/31/2015 23:09
# 669955  913454       409  8/31/2015 23:10
# 669956  913455       307  8/31/2015 23:13
# 669957  913459      1036  8/31/2015 23:11
# 669958  913460       765  8/31/2015 23:26
#
#                           start_station_name  start_station_id  \
# 0                          2nd at South Park                64
# 1                   South Van Ness at Market                66
# 2                   South Van Ness at Market                66
# 3                   South Van Ness at Market                66
# 4                   South Van Ness at Market                66
# ...                                      ...               ...
# 669954                 Embarcadero at Folsom                51
# 669955                    San Jose City Hall                10
# 669956                        Post at Kearny                47
# 669957           San Antonio Shopping Center                31
# 669958  Harry Bridges Plaza (Ferry Building)                50
#
#                end_date                          end_station_name  \
# 0        8/29/2013 9:11                         2nd at South Park
# 1        8/29/2013 9:42   San Francisco Caltrain 2 (330 Townsend)
# 2        8/29/2013 9:43   San Francisco Caltrain 2 (330 Townsend)
# 3        8/29/2013 9:43   San Francisco Caltrain 2 (330 Townsend)
# 4        8/29/2013 9:43   San Francisco Caltrain 2 (330 Townsend)
# ...                 ...                                       ...
# 669954  8/31/2015 23:22                    Embarcadero at Sansome
# 669955  8/31/2015 23:17                       San Salvador at 1st
# 669956  8/31/2015 23:18                         2nd at South Park
# 669957  8/31/2015 23:28                   Mountain View City Hall
# 669958  8/31/2015 23:39  San Francisco Caltrain (Townsend at 4th)
#
#         end_station_id  bike_id subscription_type zip_code
# 0                   64      288        Subscriber    94114
# 1                   69      321        Subscriber    94703
# 2                   69      317        Subscriber    94115
# 3                   69      316        Subscriber    94122
# 4                   69      322        Subscriber    94597
# ...                ...      ...               ...      ...
# 669954              60      487          Customer     9069
# 669955               8       68        Subscriber    95113
# 669956              64      468        Subscriber    94107
# 669957              27       35        Subscriber    95032
# 669958              70      288        Subscriber     2139
#
# [669955 rows x 11 columns]

# %%
#Creating 2 df to analyze different behaviur between Subscriber and Customer
sus_info = trip_df[trip_df["subscription_type"] == "Subscriber"]
cus_info = trip_df[trip_df["subscription_type"] == "Customer"]

# %%
#Checking some stadistics for Customers
cus_info.describe()
# Out:
#                   id       duration  start_station_id  end_station_id  \
# count  103210.000000  103210.000000     103210.000000   103210.000000
# mean   403561.959674    3752.855363         55.727168       56.107121
# std    278638.667534   13967.308290         17.300083       17.291775
# min      4078.000000      60.000000          2.000000        2.000000
# 25%    150481.250000     658.000000         48.000000       48.000000
# 50%    371751.000000    1116.000000         60.000000       60.000000
# 75%    645685.250000    2328.750000         70.000000       70.000000
# max    913453.000000  722236.000000         84.000000       84.000000
#
#              bike_id
# count  103210.000000
# mean      424.932584
# std       156.441819
# min         9.000000
# 25%       330.000000
# 50%       439.000000
# 75%       546.000000
# max       878.000000

# %%
#Checking some stadistics for Suscribers
sus_info.describe()
# Out:
#                   id       duration  start_station_id  end_station_id  \
# count  566745.000000  566745.000000     566745.000000   566745.000000
# mean   470727.497234     586.781073         58.238846       58.152607
# std    260613.881233    2420.984308         17.049599       17.164645
# min      4069.000000      60.000000          2.000000        2.000000
# 25%    244315.000000     323.000000         50.000000       50.000000
# 50%    476117.000000     476.000000         62.000000       63.000000
# 75%    698281.000000     666.000000         70.000000       70.000000
# max    913460.000000  716480.000000         84.000000       84.000000
#
#              bike_id
# count  566745.000000
# mean      428.070718
# std       152.895152
# min         9.000000
# 25%       334.000000
# 50%       441.000000
# 75%       546.000000
# max       878.000000

# %% [markdown]
# #### Analyzing most popular routes

# %%
#Generating a query for and eaiser dataframe construction
query='''
SELECT a.start_station_name as estacion_inicial, a.end_station_name as estacion_final, SUM(a.duration) AS sum, COUNT(*) AS qtd
FROM trip a
LEFT JOIN station b
ON (a.start_station_name=b.id)
GROUP BY a.start_station_name, a.end_station_name
ORDER BY 4 DESC
LIMIT 100;
'''
info = pd.read_sql_query(query, con)
info = info[(info["sum"] <=6000000 )]
display(info)

info["sum"] = info["sum"]/3600

plt.figure(figsize=(15,5))
sns.scatterplot(data=info, y='sum', x='qtd')
plt.title('Relation between hours and travels', fontsize = 10)
plt.ylabel('Duration in hours', fontsize = 12)
plt.xlabel('N° of travels' , fontsize = 12)
plt.show
# Out:
#                            estacion_inicial  \
# 0   San Francisco Caltrain 2 (330 Townsend)
# 2                           Townsend at 7th
# 3                           2nd at Townsend
# 4      Harry Bridges Plaza (Ferry Building)
# 5                    Embarcadero at Sansome
# ..                                      ...
# 95     Harry Bridges Plaza (Ferry Building)
# 96                        2nd at South Park
# 97              San Antonio Shopping Center
# 98        San Jose Diridon Caltrain Station
# 99                        Steuart at Market
#
#                               estacion_final      sum   qtd
# 0                            Townsend at 7th  1972347  6216
# 2   San Francisco Caltrain (Townsend at 4th)  1437680  5041
# 3       Harry Bridges Plaza (Ferry Building)  2821533  4839
# 4                            2nd at Townsend  2913319  4357
# 5                          Steuart at Market  2316082  4269
# ..                                       ...      ...   ...
# 95                           Townsend at 7th  1351522  1284
# 96   San Francisco Caltrain 2 (330 Townsend)   541142  1283
# 97              San Antonio Caltrain Station   620410  1278
# 98                          San Pedro Square   570710  1274
# 99                     Embarcadero at Bryant   822135  1274
#
# [97 rows x 4 columns]
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Defining the most popular routes by the one with more than 500 min as duration and with more thant 3000 travels
most_popular = info.loc[(info["sum"]>= 500 ) & (info["qtd"]>= 3000)]

#Sorting the routes by the most popular to the less popular
most_popular.sort_values(by = ["sum","qtd"],ascending = [False,False])
# Out:
#                                  estacion_inicial  \
# 9        San Francisco Caltrain (Townsend at 4th)
# 4            Harry Bridges Plaza (Ferry Building)
# 16                         Embarcadero at Sansome
# 6                           Embarcadero at Folsom
# 3                                 2nd at Townsend
# 19           Harry Bridges Plaza (Ferry Building)
# 18                              Steuart at Market
# 11       San Francisco Caltrain (Townsend at 4th)
# 13                              Steuart at Market
# 17                                 Market at 10th
# 5                          Embarcadero at Sansome
# 10  Temporary Transbay Terminal (Howard at Beale)
# 7                               Steuart at Market
# 14        San Francisco Caltrain 2 (330 Townsend)
# 0         San Francisco Caltrain 2 (330 Townsend)
# 8                               2nd at South Park
# 20       San Francisco Caltrain (Townsend at 4th)
#
#                                    estacion_final         sum   qtd
# 9            Harry Bridges Plaza (Ferry Building)  843.393889  3622
# 4                                 2nd at Townsend  809.255278  4357
# 16           Harry Bridges Plaza (Ferry Building)  806.449167  3231
# 6        San Francisco Caltrain (Townsend at 4th)  790.079722  3967
# 3            Harry Bridges Plaza (Ferry Building)  783.759167  4839
# 19       San Francisco Caltrain (Townsend at 4th)  777.157500  3033
# 18                         Embarcadero at Sansome  771.802778  3116
# 11  Temporary Transbay Terminal (Howard at Beale)  720.375000  3510
# 13       San Francisco Caltrain (Townsend at 4th)  717.490278  3477
# 17       San Francisco Caltrain (Townsend at 4th)  675.338889  3190
# 5                               Steuart at Market  643.356111  4269
# 10       San Francisco Caltrain (Townsend at 4th)  641.490556  3526
# 7                                 2nd at Townsend  625.308333  3903
# 14                             Powell Street BART  558.130000  3438
# 0                                 Townsend at 7th  547.874167  6216
# 8                               Market at Sansome  544.514167  3627
# 20                          Embarcadero at Folsom  542.790278  3031

# %% [markdown]
# <a id="Conclusion"></a>
# # Conclusion

# %% [markdown]
#     - There are some days where the average temperature is over the average temperature from the month. Would be nice to check if the NPS registered in that days is lower than the average. The heat could be a factor in the people’s mood
#
#     - There are clearly some days where the rain was heavy. It would be interesting to compare the NPS from those days to the average and check if the rain is a factor in the people’s mood
#
#     - San Francisco clearly has more site for the bicycles, would be interesting to check if the NPS is lower in other cities in comparison with SF, if that’s the case maybe the numbers of spots could be affecting the NPS
#
#     - It looks like there are so much missing spots for bicycles in the analyzed sector. We only have 5 cluster of points representing different cities. What happen with the middle section between those points? Maybe people from smalls cities have use bikes in other cities and gave a bad NPS because the does not have bikes in their cities o near their home.
#
#     - The customer rides more than the subscriber. So that means we have a target audience waiting to be converted to a Subscriber.
#
#     - We have some routes that are more popular than the other ones. Could be interesting to focus our marketing campaign on spots close to these routes or give special offers for this routes.

# %% [markdown]
# <a id="NextSteps"></a>
# # Next steps to tackle the situation

# %% [markdown]
# - Heat Topic
#     * In case we find out that the hotter days has lower NPS we can develop and engagement campaign of free water or something similar for our bikers. We need to focus in the most important routes and place a stand where people can subscribe to our product and also get some fresh for the heat.
#
#
# - Rain Topic
#     * In case we find out that the rainier days has lower NPS we can think about an investment and place roof on some of the bike spots. Something like a site where people can take their bike and escape from the rain. It would show our clients we care about them in the rainy days and improve or NPS.
#
#
# - Spots per City
#     * Taking in consideration that San Francisco has clearly more spots that the other cities we would need to create more spots in other areas. Maybe our NPS is getting lower because we are not supplying the demand of bikes. This Plan will fix that problem
#
#
# - Distance between spots
#     * This problem could be also fix by doing what is described in "Spots per City" we will need to analyze what is the optimal distance between points. With that in mind we could cover more area and reach more potential customers. In the best situation possible every person would have a bike spot at least at 10 minutes from them.
#
#
# - Customers rides more than subscribers.
#     * We could apply a discount for non-subscribers related to the distance the client travel. Something like "Subscribe now and save 20% in distances larger than 1 km" It would help people who use bikes for sport or for travel to work or house.

# %% [markdown]
# <a id="Planexecution"></a>
# # Plan Execution

# %% [markdown]
# - Heat Topic
#     * We will start with a small amount of point where we are going to give away free water and make an invitation to subscribe
#     * The starting points need to be some of the ones that are part of the most popular routes. (Take the 5 more popular stations)
#     * With the water que can give a QR code with a discount for their first subscription.
#     * Later we need to analyze or reach and results (NPS and number of New subscribers)
#     * The campaign can run 2 weeks in the hotter months. And if it works we can expand to another points. Always aiming to the popular ones.
#
#
# - Rain topic
#     * Create a roof in 3 of the most popular routes (6 stations in total)
#     * Build it in summer to check for results after winter
#     * Analyze the NPS for that specific route and check if it improves. If it does start building roofs in other popular routes.
#
#
# - Spots per city
#     * Start by adding new spots 1 or 2 per city
#     * Check if the NPS for the customers for that city changes or if we get more subscribers. If it works continue by adding points yearly
#     * This process needs a continuous analysis to see until what point the NPS improve. If the nps  or subscribers does not growth It is a signal we won’t need to create more spots.
#     * The new spots do not need to have space for a lot of bikes, with 5 spaces per new spots would be enough for the actual demand.
#
#
# - Distance between spots
#     * Implement spots per city plan
#     * Analyze optimal distance between points and create points according to that
#
#
# - Customers rides more than subscribers.
#     * Apply a discount in subscription for long travels (Bigger than 3000 for example)
#     * This discount could be show in the application or with a QR in the most popular spots
#     * The discount will work only for the first month
#     * The campaign for the discount could run in the summer to also target some tourist.
